# %% [markdown]
# Agent 생성

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(f'API Key Loaded : {os.getenv("OPENAI_API_KEY")}')
# Out:
# API Key Loaded : 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

# %%
# 필요한 라이브러리 임포트
from crewai import Agent, Task, Crew, Process  # CrewAI 핵심 클래스들
from dotenv import load_dotenv
import os

# 0. 환경 변수 로드
load_dotenv()

# 1. 에이전트 생성
agent = Agent(
    role="AI 어시스턴트",
    goal="사용자에게 간단한 환영 인사를 제공",
    backstory="당신은 친절한 AI 비서로, 언제나 정중하고 도움이 되는 인사를 건넵니다",
)

# 2. Task 생성
task = Task(
    description="사용자에게 환영 인사 한마디를 작성하세요.",  # 에이전트가 수행학 작업내용
    expected_output="한줄의 따뜻한 환영 메세지",  # 기대하는 출력 결과물
    agent=agent,
)

# %%
# 3. 크루 생성
crew = Crew(
    agents=[agent],  # 크루에 속한 에이전트 목록
    tasks=[task],  # 크루가 수행할 태스크 목록
    process=Process.sequential,  # 순차적 진행 방식으로 태스크 실행
    verbose=True,  # 실행중 로그 출력 여부
)

# 4. 크루 실행
result = crew.kickoff()

# 5. 실행 결과 출력
print(f"최종 결과 : {result}")
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 6e0c1cd7-8e11-429e-9b78-ef5b36c35dd5                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: AI 어시스턴트
# 🚀 Crew: crew
# └── 📋 Task: afb2dc07-4055-4376-a0ed-5f8d3873d7fa
# ## Task: 사용자에게 환영 인사 한마디를 작성하세요.
# 🚀 Crew: crew
# └── 📋 Task: afb2dc07-4055-4376-a0ed-5f8d3873d7fa
# 🚀 Crew: crew
# └── 📋 Task: afb2dc07-4055-4376-a0ed-5f8d3873d7fa
#     Status: Executing Task...
# 🚀 Crew: crew
# ...

# %% [markdown]
# # 치환자로 확장 하기

# %%
# 필요한 라이브러리 임포트
from crewai import Agent, Task, Crew, Process  # CrewAI 핵심 클래스들
from dotenv import load_dotenv
import os

# 0. 환경 변수 로드
load_dotenv()

# 1. 에이전트 생성
agent = Agent(
    role="{topic} AI 어시스턴트",
    goal="{topic} 사용자에게 간단한 환영 인사를 제공",
    backstory="당신은 친절한 AI 비서로,{topic}에서 언제나 정중하고 도움이 되는 인사를 건넵니다",
)

# 2. Task 생성
task = Task(
    description="{topic}에 참석한 사용자에게 환영 인사 한마디를 작성하세요.",  # 에이전트가 수행학 작업내용
    expected_output="{topic}에서의 한줄의 따뜻한 환영 메세지",  # 기대하는 출력 결과물
    agent=agent,
)
# 3. 크루 생성
crew = Crew(
    agents=[agent],  # 크루에 속한 에이전트 목록
    tasks=[task],  # 크루가 수행할 태스크 목록
    process=Process.sequential,  # 순차적 진행 방식으로 태스크 실행
    verbose=True,  # 실행중 로그 출력 여부
)

# 4. 크루 실행
inputs = {"topic": "장례식"}

result = crew.kickoff(inputs=inputs)
# 5. 실행 결과 출력
print(f"최종 결과 : {result}")
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 7699f437-0db7-4468-aa26-c46339c608d6                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 장례식 AI 어시스턴트
# 🚀 Crew: crew
# └── 📋 Task: f8ae3f95-9a41-4248-93e8-a90d7e9dd506
# ## Task: 장례식에 참석한 사용자에게 환영 인사 한마디를 작성하세요.
# 🚀 Crew: crew
# └── 📋 Task: f8ae3f95-9a41-4248-93e8-a90d7e9dd506
# 🚀 Crew: crew
# └── 📋 Task: f8ae3f95-9a41-4248-93e8-a90d7e9dd506
#     Status: Executing Task...
# 🚀 Crew: crew
# ...

# %% [markdown]
# # 에이전트 협업 (리서쳐, 라이터)

# %%
import os
from dotenv import load_dotenv
from crewai import Agent, Crew, Task, Process

load_dotenv()
open_api_key = os.getenv("OPENAI_API_KEY")
if open_api_key is None:
    raise EnvironmentError("API 키 불러오기 실패")

# 리서처 에이전트 정의
researcher = Agent(
    role="AI Researcher",
    goal="멀티 에이전트 시스템의 주요 장점을 3가지 조사하여 설명합니다.",
    backstory="다년간 AI 트렌드를 연구해온 전문가 입니다.",
)

# 라이터 에이전트 정의
writer = Agent(
    role="Technical Writer",
    goal="연구 결과를 바탕으로 간략한 결론을 작성합니다.",
    backstory="복잡한 정보를 쉽게 요약하는 작문 전문가 입니다.",
)

# 태스크 정의
research_task = Task(
    description="멀티 에이전트 시스템의 주요 장점 3가지를 조사하고 각 장점을 간략히 설명하세요",
    expected_output="3가지 장점에 대한 간단한 설명 (bullet point 목록)",
    agent=researcher,
)

write_task = Task(
    description="위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은 결론을 작성하세요.",
    expected_output="3~4문장으로 구성된 결론 단락",
    agent=writer,
    context=[research_task],  # 이전 태스크의 결과를 활용
)

# 크루 생성 (프로세스는 순차적)
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

# 실행 및  결과 출력
crew_output = crew.kickoff()

for idx, task_output in enumerate(crew_output.tasks_output, start=1):
    print(f"\n[Task {idx} Output]\n{task_output}\n")
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: ede2f9cd-e9b3-47df-b964-97e55890bda4                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# # Agent: AI Researcher
# 🚀 Crew: crew
# └── 📋 Task: a1992232-63f7-4999-9895-7797083438d3
# ## Task: 멀티 에이전트 시스템의 주요 장점 3가지를 조사하고 각 장점을 간략히
# 설명하세요
# 🚀 Crew: crew
# └── 📋 Task: a1992232-63f7-4999-9895-7797083438d3
# 🚀 Crew: crew
# └── 📋 Task: a1992232-63f7-4999-9895-7797083438d3
#     Status: Executing Task...
# 🚀 Crew: crew
# ...

# %% [markdown]
# ## 두 에이전트의 플로우
# 1. 두에이전트정의– (researcher, writer) 각기다른역할과목표설정
# 2. 두태스크정의– (research_task: 조사, write_task: 작성) 및태스크간context 연결설정
# 3. Crew 구성– 두에이전트와두태스크를하나의크루로묶고순차실행설정
# 4. Crew 실행–`kickoff()`로먼저researcher가조사수행→ 그결과를바탕으로writer가결론작성
# 5. 결과출력– 각태스크의출력물을순서대로표시(조사결과목록+ 결론글)

# %% [markdown]
# # 여러개의 치환자 사용

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
from crewai import Agent, Task, Crew, Process

# .env 파일 로드하여OPENAI_API_KEY 등환경변수설정
load_dotenv()

# 에이전트 정의
travel_agent = Agent(
    role="여행 기획자",
    goal="사용자의 요청에 따라 {place} 여행 일정을 계획하고 제안합니다",
    backstory="여행사에서 10년 경력의 전문 여행 플래너로, 다양한 국내 여행 코스를 알고 있습니다.",
    verbose=True,
)

# 부산 3일 여행 일정 작성 Task 정의
itinerary_task = Task(
    description=(
        "{place} 에서 {days}일 간 여행 일정을 계획해 주세요.\n"
        "{days}일을 1일차, 2일차와 같이 차수로 나누고, 각 일차마다 아침/점심/저녁에 할 활동을 상세히 제안하세요.\n"
        "여행 일정에는 {place}의 주요 관광지와 현지 맛집 추천을 포함하고, 교통 수단 정보나 팁이 있으면 함께 제공하세요."
    ),
    agent=travel_agent,
    expected_output="{days}일을 Day 1, Day2, ... 으로 구분된 상세 일정 제안",
)

# Crew 생성 및 실행
crew_single = Crew(
    agents=[travel_agent],
    tasks=[itinerary_task],
    process=Process.sequential,
    verbose=True,
)
print("===[단일 에이전트] 부산 3일 일정 생성 시작===")
result_single = crew_single.kickoff(inputs={"place": "부산", "days": 3})
print("===[단일 에이전트] 생성된 부산 3일 일정 ===")
print(result_single)
# Out:
# ===[단일 에이전트] 부산 3일 일정 생성 시작===
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 89542c55-315a-4ee4-902d-ec5fb11a5ecb                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# # Agent: 여행 기획자
# 🚀 Crew: crew
# └── 📋 Task: c1bc397e-6693-411f-98d9-e84bfb45ce5a
# ## Task: 부산 에서 3일 간 여행 일정을 계획해 주세요.
# 3일을 1일차, 2일차와 같이 차수로 나누고, 각 일차마다 아침/점심/저녁에 할 활동을
# 상세히 제안하세요.
# 🚀 Crew: crew
# └── 📋 Task: c1bc397e-6693-411f-98d9-e84bfb45ce5a
# 여행 일정에는 부산의 주요 관광지와 현지 맛집 추천을 포함하고, 교통 수단 정보나
# ...

# %% [markdown]
# # 웹 검색 도구를 장착하여 에이전트 정의

# %%
# %pip install -U duckduckgo-search

# %%
from crewai.tools import BaseTool
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
from crewai import Agent, Task, Crew, Process

# .env 파일로드하여OPENAI_API_KEY 등환경변수설정
load_dotenv()


class MyCustomDuckDuckGoTool(BaseTool):
    name: str = "DuckDuckGo Search Tool"
    description: str = "웹에서최신정보를검색할수있는도구입니다."

    def _run(self, query: str) -> str:
        duckduckgo_tool = DuckDuckGoSearchRun()
        response = duckduckgo_tool.invoke(query)
        return response


# DuckDuckGo 검색도구인스턴스생성
search_tool = MyCustomDuckDuckGoTool()

# 정보 조사 에이전트 정의
research_agent = Agent(
    role="정보 조사자",
    goal="{place} 여행에 필요한 최신 정보를 조사하여 제공합니다.",
    backstory="온라인 정보 검색에 능통한 여행 정보 전문가 입니다.",
    tools=[search_tool],
    verbose=True,
)

# 일정 작성 에이전트 정의
planner_agent = Agent(
    role="여행 일정 기획자",
    goal="제공된 정보를 활용해 완성도 높은 {place} 여행 일정을 작성합니다.",
    backstory="국내 여행 일정을 여러 차례 기획한 경험이 풍부한 전문가입니다",
    verbose=True,
)

# 정보 조사 Task 정의
research_task = Task(
    description=(
        "{place} 여행을 위해 알아야 할 핵심 정보를 조사하세요.\n"
        "{place}의 인기 관광지 목록, 지역별 맛집 추천, 이동시 유용한 교통 정보 등을 최신 자료를 기반으로 정리해 주세요."
    ),
    agent=research_agent,
    expected_output="한국어로 작성된 {place} 여행에 대한 요약 정보 목록",
)

# 일정 작성 Task 정의 (이전 Task 결과를 context 로 활용)
planning_task = Task(
    description=(
        "위의 조사 결과를 참고하여 {place}에서 {days}일 동안 머무는 여행 일정을 작성해 주세요.\n"
        "각 날짜별로 오전/오후/저녁 계획을 세우고, 조사된 관광지와 맛집 정보를 일정에 반영하세요.\n"
        "일정에는 방문지에 대한 간단한 설명이나 여행 팁 도 포함해 주세요."
    ),
    agent=planner_agent,
    context=[research_task],
    expected_output="한국어로 작성된 조사 정보를 반영한 {days}일 간의 여행 일정",
)

# 2개의 에이전트를 크루로 묶어 순차 실행
crew_multi = Crew(
    agents=[research_agent, planner_agent],
    tasks=[research_task, planning_task],
    process=Process.sequential,
    verbose=True,
)

print("\n===[협업 에이전트] 부산 3일 일정 생성 시작===")
result_multi = crew_multi.kickoff(inputs={"place": "부산", "days": 3})
print("===[협업 에이전트] 생성된 부산 3일 일정 ===")
print(result_multi)
# Out:
# ===[협업 에이전트] 부산 3일 일정 생성 시작===
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: c0e2fdc5-861d-410d-abb0-50029072c1aa                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# # Agent: 정보 조사자
# 🚀 Crew: crew
# └── 📋 Task: aa795e87-e2cf-4c19-8406-53d89529714b
# ## Task: 부산 여행을 위해 알아야 할 핵심 정보를 조사하세요.
# 🚀 Crew: crew
# └── 📋 Task: aa795e87-e2cf-4c19-8406-53d89529714b
# 부산의 인기 관광지 목록, 지역별 맛집 추천, 이동시 유용한 교통 정보 등을 최신
# 자료를 기반으로 정리해 주세요.
# 🚀 Crew: crew
# ...

# %% [markdown]
# # 프롬프트 개선

# %%
from crewai.tools import BaseTool
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
from crewai import Agent, Task, Crew, Process

# .env 파일로드하여OPENAI_API_KEY 등환경변수설정
load_dotenv()


class MyCustomDuckDuckGoTool(BaseTool):
    name: str = "DuckDuckGo Search Tool"
    description: str = "웹에서최신정보를검색할수있는도구입니다."

    def _run(self, query: str) -> str:
        duckduckgo_tool = DuckDuckGoSearchRun()
        response = duckduckgo_tool.invoke(query)
        return response


# DuckDuckGo 검색도구인스턴스생성
search_tool = MyCustomDuckDuckGoTool()

# 정보 조사 에이전트 정의
research_agent = Agent(
    role="정보 조사자",
    goal="{place} 여행에 필요한 최신 정보를 조사하여 제공합니다.",
    backstory="온라인 정보 검색에 능통한 여행 정보 전문가 입니다.",
    tools=[search_tool],
    verbose=True,
)

# 일정 작성 에이전트 정의
planner_agent = Agent(
    role="여행 일정 기획자",
    goal="제공된 정보를 활용해 완성도 높은 {place} 여행 일정을 작성합니다.",
    backstory="국내 여행 일정을 여러 차례 기획한 경험이 풍부한 전문가입니다",
    verbose=True,
)

# 정보 조사 Task 정의
research_task = Task(
    description=(
        "{place} 여행을 위해 알아야 할 핵심 정보를 조사하세요.\n"
        "{place}의 인기 관광지 목록, 지역별 맛집 추천, 이동시 유용한 교통 정보 등을 최신 자료를 기반으로 정리해 주세요."
    ),
    agent=research_agent,
    expected_output="한국어로 작성된 {place} 여행에 대한 요약 정보 목록",
)

# 일정 작성 Task 정의 (이전 Task 결과를 context 로 활용)
planning_task = Task(
    description=(
        "위의조사결과를참고하여{place}에서{days}일동안머무는여행일정을작성해주세요.\n"
        "각날짜별로오전/오후/저녁계획을세우고, 조사된관광지와맛집정보를일정에반영하세요.\n"
        "가능하면예산은하루10만원내외로맞추고, 이동은모두대중교통을이용하는것으로고려하세요.\n"
        "버스정류장및지하철역을포함한대중교통경로를제안해주세요.\n"
        "버스및지하철을이용할때의소요시간도포함해주세요.\n"
        "일정에는방문지에대한간단한설명이나여행팁도포함해주세요. 결과는한국어로작성해주세요.\n"
    ),
    agent=planner_agent,
    context=[research_task],
    expected_output="예산과 교통을 고려한 {days}일 간의 여행 일정",
)

# 2개의 에이전트를 크루로 묶어 순차 실행
crew_multi = Crew(
    agents=[research_agent, planner_agent],
    tasks=[research_task, planning_task],
    process=Process.sequential,
    verbose=True,
)

print("\n===[협업 에이전트] 부산 3일 일정 생성 시작===")
result_multi = crew_multi.kickoff(inputs={"place": "부산", "days": 3})
print("===[협업 에이전트] 생성된 부산 3일 일정 ===")
print(result_multi)
# Out:
# ===[협업 에이전트] 부산 3일 일정 생성 시작===
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 14528386-8637-43ae-9e4d-a117f2122552                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 정보 조사자
# 🚀 Crew: crew
# └── 📋 Task: 8717fa4c-bc96-454e-acdb-f939e78d6055
# ## Task: 부산 여행을 위해 알아야 할 핵심 정보를 조사하세요.
# 🚀 Crew: crew
# └── 📋 Task: 8717fa4c-bc96-454e-acdb-f939e78d6055
# 부산의 인기 관광지 목록, 지역별 맛집 추천, 이동시 유용한 교통 정보 등을 최신
# 자료를 기반으로 정리해 주세요.
# 🚀 Crew: crew
# ...

# %% [markdown]
# # 나만의 에이전트 만들기

# %%
from crewai.tools import BaseTool
from langchain_community.tools import DuckDuckGoSearchRun
from dotenv import load_dotenv
import os
from crewai import Agent, Task, Crew, Process

# .env 파일 로드하여 OPENAI_API_KEY 등 환경 변수 설정
load_dotenv()


# DuckDuckGo 검색 툴 정의
class MyCustomDuckDuckGoTool(BaseTool):
    name: str = "DuckDuckGo Stock News Tool"
    description: str = "특정 주식 종목에 대한 최신 뉴스를 검색하는 도구입니다."

    def _run(self, query: str) -> str:
        duckduckgo_tool = DuckDuckGoSearchRun()
        return duckduckgo_tool.invoke(query)


# DuckDuckGo 툴 인스턴스 생성
search_tool = MyCustomDuckDuckGoTool()

# 뉴스 조사 에이전트 정의
news_agent = Agent(
    role="증시 뉴스 분석가",
    goal="{ticker} 관련 최신 뉴스를 수집하고 요약합니다.",
    backstory="증권사 리서치 센터에서 활동 중인 금융 뉴스 전문가입니다.",
    tools=[search_tool],
    verbose=True,
)

# 의견 작성 에이전트 정의
opinion_agent = Agent(
    role="투자 조언 전문가",
    goal="제공된 뉴스를 기반으로 간단한 투자 의견을 작성합니다.",
    backstory="주식 초보자에게도 이해하기 쉬운 설명을 제공하는 투자 전문가입니다.",
    verbose=True,
)

# 뉴스 조사 Task 정의
news_task = Task(
    description="{ticker}에 대한 최신 뉴스 3~5개를 수집하고 요약해 주세요. 주요 사건 위주로 간결하게 정리해 주세요.",
    agent=news_agent,
    expected_output="{ticker} 관련 뉴스 요약 리스트",
)

# 투자 의견 Task 정의
opinion_task = Task(
    description="위 뉴스들을 참고하여, 현재 {ticker} 주식의 투자 관점에서 주의할 점이나 기대 요인을 3~4문장으로 정리해 주세요.",
    agent=opinion_agent,
    context=[news_task],
    expected_output="{ticker}에 대한 요약 투자 의견",
)

# 크루 정의 (순차 실행)
crew_multi = Crew(
    agents=[news_agent, opinion_agent],
    tasks=[news_task, opinion_task],
    process=Process.sequential,
    verbose=True,
)

print("\n===[협업 에이전트] 삼성전자 뉴스 기반 투자 분석 시작===")
result_multi = crew_multi.kickoff(inputs={"ticker": "삼성전자"})
print("===[최종 결과] 삼성전자 뉴스 기반 투자 분석 ===")
print(result_multi)
# Out:
# ===[협업 에이전트] 삼성전자 뉴스 기반 투자 분석 시작===
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 089406ee-7071-455e-ac56-d817bddd5504                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 증시 뉴스 분석가
# 🚀 Crew: crew
# └── 📋 Task: 68744063-0f2d-4af8-a522-6fe83cc06ed1
# ## Task: 삼성전자에 대한 최신 뉴스 3~5개를 수집하고 요약해 주세요. 주요 사건
# 위주로 간결하게 정리해 주세요.
# 🚀 Crew: crew
# └── 📋 Task: 68744063-0f2d-4af8-a522-6fe83cc06ed1
# 🚀 Crew: crew
# └── 📋 Task: 68744063-0f2d-4af8-a522-6fe83cc06ed1
# ...

# %% [markdown]
# # CrewAI 의 Tools 사용

# %%
from tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool
from crewai import Agent, Task, Crew, Process

# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()

news_agent = Agent(
    role="뉴스 분석가",
    goal="최신 뉴스를 검색하여 요약",
    backstory="뉴스 분석 전문 AI 기자",
    tools=[search_tool, scrape_tool],
    verbose=True,
)

news_task = Task(
    description="최근 인공지능 관련 뉴스 3건을 요약하고 링크 제공",
    expected_output="한국어로 작성된 뉴스 3건의 요약 및 링크",
    agent=news_agent,
)

crew = Crew(
    agents=[news_agent], tasks=[news_task], process=Process.sequential, verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: c7a41a54-9f5f-4068-8828-6e5784f08c56                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# # Agent: 뉴스 분석가
# 🚀 Crew: crew
# └── 📋 Task: 806063ad-19ec-4300-b191-ac21ac1b600f
# ## Task: 최근 인공지능 관련 뉴스 3건을 요약하고 링크 제공
# 🚀 Crew: crew
# └── 📋 Task: 806063ad-19ec-4300-b191-ac21ac1b600f
# 🚀 Crew: crew
# └── 📋 Task: 806063ad-19ec-4300-b191-ac21ac1b600f
#     Status: Executing Task...
# 🚀 Crew: crew
# ...

# %% [markdown]
# ## Tools 예제2

# %%
from tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool
from crewai import Agent, Task, Crew, Process

# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()

recipe_agent = Agent(
    role="요리 분석가",
    goal="요리 레시피 추천 및 요약",
    backstory="글로벌 요리 전문 셰프",
    tools=[search_tool, scrape_tool],
    verbose=True,
)

recipe_task = Task(
    description="채식 파스타 레시피 추천, 재료 및 조리법 안내",
    expected_output="한국어로 작성된 채식 파스타 레시피(재료 및 조리법)",
    agent=recipe_agent,
)

crew = Crew(
    agents=[recipe_agent], tasks=[recipe_task], process=Process.sequential, verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: b2edeb15-de7c-438f-a24f-5a9647e49561                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 요리 분석가
# 🚀 Crew: crew
# └── 📋 Task: 1f704ac9-77c7-44ef-9835-763e3963fb33
# ## Task: 채식 파스타 레시피 추천, 재료 및 조리법 안내
# 🚀 Crew: crew
# └── 📋 Task: 1f704ac9-77c7-44ef-9835-763e3963fb33
# 🚀 Crew: crew
# └── 📋 Task: 1f704ac9-77c7-44ef-9835-763e3963fb33
#     Status: Executing Task...
# 🚀 Crew: crew
# ...

# %% [markdown]
# ## Tools 예제3

# %%
from tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool
from crewai import Agent, Task, Crew, Process

# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()

travel_agent = Agent(
    role="여행 전문가",
    goal="최적의 여행 일정과 예산 계획 제공",
    backstory="다년간 여행 플래너 경험 보유",
    tools=[search_tool, scrape_tool],
    verbose=True,
)

travel_task = Task(
    description="파리 5일 여행 일정(문화, 미식 포함), 예상 예산은 검색해서 알맞게 적용하여 안내",
    expected_output="한국어로 작성된 5일간 파리 여행에 대한 상세한 일정과 예산 계산 결과",
    agent=travel_agent,
)

crew = Crew(
    agents=[travel_agent], tasks=[travel_task], process=Process.sequential, verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 85a5649c-1b9b-4dc5-9c15-6af6a02ecd55                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 여행 전문가
# 🚀 Crew: crew
# └── 📋 Task: 8d479296-f147-4b37-80c7-67749f80c9d1
# ## Task: 파리 5일 여행 일정(문화, 미식 포함), 예상 예산은 검색해서 알맞게
# 적용하여 안내
# 🚀 Crew: crew
# └── 📋 Task: 8d479296-f147-4b37-80c7-67749f80c9d1
# 🚀 Crew: crew
# └── 📋 Task: 8d479296-f147-4b37-80c7-67749f80c9d1
#     Status: Executing Task...
# 🚀 Crew: crew
# ...

# %% [markdown]
# # 순차적 실행과 계층적 실행

# %% [markdown]
# ## 순차적 실행

# %%
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
from tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool

load_dotenv()  # .env 파일에서 API 키등환경변수로드

# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()

# 뉴스분석Agent 정의
news_agent = Agent(
    role="뉴스분석가",
    goal="최신여행관련뉴스를검색하고요약제공",
    backstory="뉴스 분석전문AI 기자",
    tools=[search_tool, scrape_tool],
    # 웹검색및스크래핑도구사용
    verbose=False,
)
# 여행계획Agent 정의
travel_agent = Agent(
    role="여행전문가",
    goal="뉴스내용을바탕으로현실적이고매력적인여행일정구성",
    backstory="다년간의여행플래너경험보유",
    tools=[search_tool, scrape_tool, calculator_tool],  # 필요한 경우 계산기 도구도 사용
    verbose=False,
)

# 요리추천Agent 정의
recipe_agent = Agent(
    role="요리전문가",
    goal="여행지에서즐길수있는적절한현지요리레시피추천",
    backstory="글로벌요리전문가AI 셰프",
    tools=[search_tool, scrape_tool],
    verbose=False,
    # 웹검색및스크래핑도구사용
)
# Task 정의: 각 에이전트에게할일할당
news_task = Task(
    description="최근 일주일내국내여행과관련된중요한뉴스1건을한국어로요약해줘.",
    expected_output="한국어로 작성된여행관련뉴스1건의제목, 요약, 링크",
    agent=news_agent,
)
travel_task = Task(
    description="위에서 제공된최신여행뉴스를참고하여3일동안의여행일정을한국어로작성해줘.",
    expected_output="한국어로 작성된상세한3일여행일정",
    agent=travel_agent,
)

recipe_task = Task(
    description="여행 일정에포함된지역에서추천할만한현지음식레시피1개를한국어로제공해줘.",
    expected_output="한국어로 작성된현지음식이름, 재료목록, 상세한조리법",
    agent=recipe_agent,
)
# Crew 생성및실행(순차적프로세스지정)
crew = Crew(
    agents=[news_agent, travel_agent, recipe_agent],
    tasks=[news_task, travel_task, recipe_task],
    process=Process.sequential,  # 순차적으로 Task들을 처리
    verbose=False,
)


def run_sequential_scenario():
    result = crew.kickoff()  # 순차적 프로세스시작
    print("[순차적 시나리오최종결과]\n", result)


if __name__ == "__main__":
    run_sequential_scenario()
# Out:
# [순차적 시나리오최종결과]
#  **강원도 전통 음식 레시피: 초당 순두부찌개**
#
# **재료:**
# - 초당 순두부 1팩
# - 대파 1대
# - 양파 1개
# - 마늘 3쪽
# - 멸치육수 4컵 (또는 물)
# - 고춧가루 2큰술
# - 참기름 1큰술
# - 간장 1큰술
# - 소금, 후추 약간
# - 선택 재료: 다진 고기 (예: 돼지고기)
#
# **조리법:**
# 1. **재료 준비**: 대파는 송송 썰고, 양파는 채썰어 준비합니다. 마늘은 다져주세요.
# 2. **육수 만들기**: 냄비에 멸치를 넣고 물을 끓여 육수를 만듭니다. (약 10분 정도 끓인 후 멸치는 제거)
# 3. **양파와 마늘 볶기**: 별도의 팬에 참기름을 두르고, 다진 마늘과 양파를 넣고 중불에서 볶아 향을 내줍니다.
# 4. **육수와 순두부 추가**: 볶은 양파와 마늘에 육수를 붓고 끓이기 시작합니다. 이후, 초당 순두부를 숟가락으로 퍼뜨리듯 추가하세요.
# 5. **간 하기**: 고춧가루, 간장을 넣고 잘 저은 후, 필요하면 소금과 후추로 간을 맞춥니다.
# 6. **대파 추가**: 마지막으로 썰어둔 대파를 넣고, 끓어오르면 불을 끄고 그릇에 담아 서빙합니다.
# 7. **서빙**: 밥과 함께 따뜻하게 드세요. 취향에 따라 쌈장이나 김치와 함께 즐기면 더욱 맛있습니다.
#
# **맛있게 드세요!**

# %% [markdown]
# ## 계층적 구조

# %%
from crewai import Agent, Task, Crew, Process
from tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool

# 도구인스턴스생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()
# 총괄여행플래너(관리자Agent)
planner_agent = Agent(
    role="총괄 여행 플래너",
    goal="최적의 서울 근교 1박 2일 여행 일정과 추천 음식을 종합하여 최종 여행 계획서를 작성",
    backstory="10년 경력의 베테랑 여행 컨설턴트로 다양한 분야의 의견을 취합하여 여행 계획을 완성합니다.",
    allow_delegation=True,  # 다른 에이전트에게업무위임을허용
    verbose=False,
)

# 여행전문가Agent (여행일정추천담당)
travel_agent = Agent(
    role="여행 전문가",
    goal="최신 여행 트렌드를 조사하여 서울 근교의 인기 있는 여행지와 일정을 제안",
    backstory="국내 여행지에 대해 잘 알고 있는 전문가로, 최근의 여행 트렌드를 바탕으로 관광지를 추천합니다.",
    tools=[search_tool],
    verbose=False,
)
# 요리전문가Agent (음식추천담당)
culinary_agent = Agent(
    role="요리전문가",
    goal="추천된 여행지와 잘 어울리는 현지 음식 및 레시피를 추천",
    backstory="국내 각 지역의 음식 문화와 레시피에 능통한 전문가로, 여행지에 어울리는 음식을 추천합니다.",
    tools=[search_tool],
    verbose=False,
)

# Task 정의(총괄플래너에게최종여행계획서작성지시)
planner_task = Task(
    description=(
        "국내 최신 여행 트렌드가 반영된 서울 근교의1박2일 여행 일정을 작성하고, "
        "각 여행지와 잘 어울리는 현지 음식과 레시피를 포함하여 여행 계획서를 한국어로 작성해주세요."
    ),
    expected_output=(
        "최신 여행 트렌드를 반영한 서울 근교 1박 2일 여행 일정과"
        "각 여행지의 현지 음식 및 간단한 레시피를 포함한 한국어 여행 계획서"
    ),
    agent=planner_agent,
)

# Crew 구성(계층적프로세스사용)
crew = Crew(
    agents=[travel_agent, culinary_agent],  # 하위실행에참여할에이전트들(관리자제외)
    tasks=[planner_task],
    process=Process.hierarchical,
    manager_agent=planner_agent,  # 총괄여행플래너를매니저로지정
)
# Crew 실행
if __name__ == "__main__":
    result = crew.kickoff()
    print("\n\n최종여행계획서:\n")
    print(result)
# Out:
# 최종여행계획서:
#
# 서울 근교 1박 2일 여행 계획서
#
# **여행지:** 가평 & 양평
#
# ---
#
# ### **1일차: 가평**
#
# **오전 9시:** 서울 출발
# - 출발 후 약 1시간 30분 소요
#
# **오전 11시:** 남이섬 관광
# - 현지 관광지로 유명한 남이섬을 방문하여 자연 경관 감상 및 수목 명소 탐방
#
# **점심:** 남이섬 내 "남이섬 한정식"
# - 레시피:
#   - **재료:** 고등어구이, 잡곡밥, 계란찜, 나물 무침 등
#   - **조리법:**
#     1. 고등어에 소금과 후추를 뿌리고 팬에 굽기
#     2. 잡곡밥을 지어 제공
#     3. 여러 가지 나물을 데치고 간장으로 양념
#     4. 마지막에 계란을 풀어 계란찜 완성
#
# **오후 1시 30분:** 아침고요수목원 방문
# - 다양한 식물과 정원에서 힐링하는 시간 가지기
# - 현지 카페에서 커피 한 잔의 여유도 추천
#
# **오후 4시:** 가평 아침고요 테마파크 방문
# - 숲 속 자연과 함께 예술작품 감상
#
# **저녁:** 가평의 "닭갈비" 맛집
# - 레시피:
#   - **재료:** 닭고기, 배추, 고추장, 간장, 마늘, 대파 등
#   - **조리법:**
#     1. 닭고기를 큐브 모양으로 썰고 양념장에 재우기
#     2. 달군 팬에 닭고기와 채소들을 넣고 볶기
#     3. 볶다가 주먹밥을 곁들여 함께 제공하기
#
# **밤 9시:** 숙소 체크인 - 가평 펜션
# - 자연속에서 캠프파이어 및 야경 감상
#
# ---
#
# ### **2일차: 양평**
#
# **오전 8시:** 아침 식사
# - 숙소에서 간단한 조식 제공
#
# **오전 10시:** 양평 두물머리 방문
# - 한강과 북한강이 만나는 지점에서 자전거 타기 또는 산책
#
# **점심:** 양평의 "메기 매운탕"
# - 레시피:
#   - **재료:** 메기, 무, 대파, 고추가루, 마늘 등
#   - **조리법:**
# ...

# %%
# %pip install yfinance

# %%
from crewai import Agent, Task, Crew, Process
from crewai.tools import BaseTool
import yfinance as yf
from langchain_community.tools import DuckDuckGoSearchRun


### --- 툴 래퍼들 --- ###
class FinanceTool(BaseTool):
    name: str = "Finance Data Tool"
    description: str = "주식 가격과 재무 지표를 가져옵니다."

    def _run(self, ticker: str) -> dict:
        info = yf.Ticker(ticker).info
        return {
            "price": info.get("currentPrice"),
            "pe": info.get("trailingPE"),
            "eps": info.get("trailingEps"),
            "beta": info.get("beta"),
        }


class MyCustomDuckDuckGoTool(BaseTool):
    name: str = "DuckDuckGo Stock News Tool"
    description: str = "특정 주식 종목에 대한 최신 뉴스를 검색하는 도구입니다."

    def _run(self, query: str) -> str:
        duckduckgo_tool = DuckDuckGoSearchRun()
        return duckduckgo_tool.invoke(query)


finance_tool = FinanceTool()
news_tool = MyCustomDuckDuckGoTool()

### --- 에이전트 --- ###
news_agent = Agent(
    role="News 연구원",
    goal="{ticker} 관련 최신 뉴스를 요약한다.",
    backstory="금융 뉴스 크롤링과 요약에 특화된 애널리스트야.",
    tools=[news_tool],
    verbose=True,
)

fund_agent = Agent(
    role="펀더멘털 애널리스트",
    goal="{ticker}의 재무 상태를 평가한다.",
    backstory="밸류에이션 모델링 5년 차 애널리스트야.",
    tools=[finance_tool],
    verbose=True,
)

risk_agent = Agent(
    role="리스크 매니저",
    goal="{ticker}의 변동성·베타를 분석해 위험도를 산출한다.",
    backstory="시장 리스크 관리 경험이 풍부한 전문가야.",
    tools=[finance_tool],
    verbose=True,
)

port_agent = Agent(
    role="포트폴리오 메이커",
    goal="{budget}원 예산과 {risk} 리스크 성향에 맞춰 자산 비중을 추천한다.",
    backstory="자산배분 전략 컨설턴트로 활동 중이야.",
    verbose=True,
)

### --- 관리자 에이전트 정의 --- ###
manager_agent = Agent(
    role="투자 분석 관리자",
    goal=(
        "{ticker} 주식을 분석하기 위해 아래 JSON 양식으로 DelegateWorkTool을 호출하세요:\n"
        "```json\n"
        "{\n"
        '  "coworker": "News 연구원",\n'
        '  "task": "AAPL 관련 최신 뉴스를 3줄 요약하고 링크 제공",\n'
        '  "context": "AAPL은 현재 상승세이며, 곧 실적 발표가 있습니다."\n'
        "}\n"
        "```\n"
        "이제 해당 형식에 맞춰 순수 문자열로 위임해주세요."
    ),
    backstory="여러 전문가(서브 에이전트)에게 업무를 위임하고 총괄하는 투자 전략 컨설턴트야.",
    allow_delegation=True,  # 하위 에이전트에게 업무를 위임할 수 있게
    verbose=True,
)

manager_task = Task(
    description=(
        "지금부터 {ticker}에 대해 다음 과정을 진행해:  \n"
        "1. News 연구원이 최신 뉴스 3줄 요약 및 링크 제공  \n"
        "2. 펀더멘털 애널리스트가 PER, EPS 기반 투자 매력도 평가  \n"
        "3. 리스크 매니저가 최근 1년 변동성·β로 위험 등급 산출  \n"
        "4. 포트폴리오 메이커가 예산 : {budget}, 리스크 : {risk} 반영해 포트폴리오 표 생성  \n"
        "이 네 결과를 종합해서, 한글로 깔끔한 최종 투자 리포트를 만들어 줘."
        "하위 에이전트에게 task와 context를 반드시 순수한 텍스트(문장)로만 제공."
    ),
    expected_output=(
        "1) 뉴스 요약 3줄  \n"
        "2) 재무 평가 결과(투자 매력도)  \n"
        "3) 위험 등급(숫자 포함)  \n"
        "4) 표 형태 포트폴리오 비중 및 이유  \n"
        "5) 위 모든 세부 결과를 한 문서로 요약한 최종 리포트"
    ),
    agent=manager_agent,
)

### --- 크루 실행 (계층적 구조) --- ###
crew = Crew(
    agents=[news_agent, fund_agent, risk_agent, port_agent],
    tasks=[manager_task],
    process=Process.hierarchical,
    manager_agent=manager_agent,
)

# 실제 구동
result = crew.kickoff(inputs={"ticker": "AAPL", "budget": 10000000, "risk": "중간"})
print(result)
# Out:
# # Agent: 투자 분석 관리자
# ## Task: 지금부터 AAPL에 대해 다음 과정을 진행해:
# 1. News 연구원이 최신 뉴스 3줄 요약 및 링크 제공
# 2. 펀더멘털 애널리스트가 PER, EPS 기반 투자 매력도 평가
# 3. 리스크 매니저가 최근 1년 변동성·β로 위험 등급 산출
# 4. 포트폴리오 메이커가 예산 : 10000000, 리스크 : 중간 반영해 포트폴리오 표 생성
# 이 네 결과를 종합해서, 한글로 깔끔한 최종 투자 리포트를 만들어 줘.하위 에이전트에게 task와 context를 반드시 순수한 텍스트(문장)로만 제공.
#
#
# # Agent: 투자 분석 관리자
# ## Thought: Thought: AAPL에 대한 첫 번째 작업을 수행할 필요가 있다. News 연구원에게 최신 뉴스를 요약하도록 위임하겠다.
# ## Using tool: Delegate work to coworker
# ## Tool Input:
# "{\"coworker\": \"News \\uc5f0\\uad6c\\uc6d0\", \"task\": \"AAPL \\uad00\\ub828 \\ucd5c\\uc2e0 \\ub274\\uc2a4\\ub97c 3\\uc904 \\uc694\\uc57d\\ud558\\uace0 \\ub9c1\\ud06c \\uc81c\\uacf5\", \"context\": \"AAPL\\uc740 \\ud604\\uc7ac \\uc0c1\\uc2b9\\uc138\\uc774\\uba70, \\uace7 \\uc2e4\\uc801 \\ubc1c\\ud45c\\uac00 \\uc788\\uc2b5\\ub2c8\\ub2e4.\"}"
# ## Tool Output:
#
# Error executing tool. coworker mentioned not found, it must be one of the following options:
# - 투자 분석 관리자
#
# # Agent: 투자 분석 관리자
# ...
